# %% [markdown]
# <a href="https://colab.research.google.com/github/Frezga/project-AI-reasoning/blob/main/AI_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

SHARED_FOLDER_PATH = '/content/drive/MyDrive/PROJEK_AI_KELOMPOK_5'
os.chdir(SHARED_FOLDER_PATH)

print("Workspace berhasil diinisialisasi. Direktori saat ini:", os.getcwd())
